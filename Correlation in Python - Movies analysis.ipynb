# %%
# import libraries

import pandas as pd
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use("ggplot")
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #adjust the configururation of plots


import numpy as np

# %%
#read in the data
df = pd.read_csv(r"C:\Users\lochr\Python\Python projects\movies.csv")

# %%
#look at the data
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#check and see if there is any missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
df.dropna(inplace=True)
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
#data types of the columns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
#              ...
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# Length: 15, dtype: object

# %%
#change data type of the column 
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')
df['votes'] = df['votes'].astype('int64')
df['runtime'] = df['runtime'].astype('int64')

# %%
#change from obj to string
df['released'] = df['released'].astype(str)
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# ...

# %%
df.dtypes
# Out:
# name        object
# rating      object
# genre       object
# year         int64
# released    object
#              ...
# country     object
# budget       int64
# gross        int64
# company     object
# runtime      int64
# Length: 15, dtype: object

# %%
pattern = r'([A-Za-z]+\s\d{1,2},\s\d{4})'
df['released'] = df['released'].str.extract(pattern)
df['released'] = pd.to_datetime(df['released'], format='%B %d, %Y')
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year   released  score    votes         director  \
# ...

# %%
df['released'] = df['released'].astype(str)
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year    released  score    votes         director  \
# ...

# %%
df['yearcorrect'] = df['released'].str[:4]
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year    released  score    votes         director  \
# ...

# %%
df = df.sort_values(by='gross', inplace = False, ascending = False)

# %%
pd.set_option('display.max_rows', 100)

# %%
#drop any duplicates
df['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
# 4007                               i5 Films
# 6793                             i am OTHER
# 6420                                   erbp
#                        ...
# 385                        1818 Productions
# 2929                          1492 Pictures
# 3024                        .406 Production
# 7525    "Weathering With You" Film Partners
# 4345        "DIA" Productions GmbH & Co. KG
# Name: company, Length: 1475, dtype: object

# %%
df['company'].head()
# Out:
# 5445    Twentieth Century Fox
# 7445           Marvel Studios
# 3045    Twentieth Century Fox
# 6663                Lucasfilm
# 7244           Marvel Studios
# Name: company, dtype: object

# %%
#correlation with gross
#guesses:
#budget high correlation
#company high correlation

# %%
#build a scatter plot with budget vs gross revenue

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('budget vs gross earnings correlation')
plt.xlabel('budget')
plt.ylabel('gross')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#         released  score    votes             director  \
# ...

# %%
#plot the budget vs gross using seaborn

sns.regplot(x='budget', y='gross', data =df, scatter_kws={'color':'red'}, line_kws={'color':'blue'})
plt.title('budget vs gross earnings regression plot')
# Out:
# Text(0.5, 1.0, 'budget vs gross earnings regression plot')

# %%
#correlation

# %%
df.corr() #pearson, #kendall, #spearman
# Out:
# C:\Users\lochr\AppData\Local\Temp\ipykernel_18688\1826831626.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr() #pearson, #kendall, #spearman
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
df.corr(method ="pearson" ) #pearson, #kendall, #spearman
# Out:
# C:\Users\lochr\AppData\Local\Temp\ipykernel_18688\3691358959.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method ="pearson" ) #pearson, #kendall, #spearman
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
df.corr(method ="spearman" ) #pearson, #kendall, #spearman
# Out:
# C:\Users\lochr\AppData\Local\Temp\ipykernel_18688\601167887.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method ="spearman" ) #pearson, #kendall, #spearman
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.057741  0.427623  0.312886  0.351045  0.095444
# score    0.057741  1.000000  0.495409 -0.009971  0.183192  0.412155
# votes    0.427623  0.495409  1.000000  0.493461  0.745793  0.300621
# budget   0.312886 -0.009971  0.493461  1.000000  0.692958  0.330794
# gross    0.351045  0.183192  0.745793  0.692958  1.000000  0.257400
# runtime  0.095444  0.412155  0.300621  0.330794  0.257400  1.000000

# %%
df.corr(method ="kendall" ) #pearson, #kendall, #spearman
# Out:
# C:\Users\lochr\AppData\Local\Temp\ipykernel_18688\3409695138.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method ="kendall" ) #pearson, #kendall, #spearman
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.039389  0.296512  0.220833  0.239539  0.064824
# score    0.039389  1.000000  0.350185 -0.006406  0.124943  0.292254
# votes    0.296512  0.350185  1.000000  0.346274  0.553625  0.205344
# budget   0.220833 -0.006406  0.346274  1.000000  0.512057  0.231278
# gross    0.239539  0.124943  0.553625  0.512057  1.000000  0.176979
# runtime  0.064824  0.292254  0.205344  0.231278  0.176979  1.000000

# %%
#high correlation between budget and gross: Pearson: 0.740247, spearman:0.692958,kendall: 0.512057

# %%
corr_matrix = df.corr(method ="pearson" ) 
sns.heatmap(corr_matrix,annot=True)
plt.title('correlation matrix for numeric features')
plt.xlabel('movies features')
plt.ylabel('movies features')

plt.show()
# Out:
# C:\Users\lochr\AppData\Local\Temp\ipykernel_18688\4252078800.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr(method ="pearson" )

# %%
pd.set_option('display.max_rows', 10)

# %%
#looks at company
df
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#         released  score    votes             director  \
# ...

# %%
df_numerized = df.copy()

for col_name in df_numerized.columns:
    if (df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
df_numerized
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 5445   386       5      0  2009      1695    7.8  1100000       785    1263
# 7445   388       5      0  2019      2329    8.4   903000       105     513
# 3045  4909       5      6  1997       928    7.8  1100000       785    1263
# 6663  3643       5      0  2015      2119    7.8   876000       768    1806
# 7244   389       5      0  2018      2262    8.4   897000       105     513
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 5640  3794       6      6  2009      2059    5.8     3500       585    2924
# 2434  2969       5      0  1993       714    4.5     1900      1805    3102
# 3681  1595       3      6  2000      1141    6.8    43000       952    1683
# 272   2909       6      9  1982        64    3.9     2300       261      55
# 3203  4966       5      4  1997       916    5.7     5800       651     161
#
# ...

# %%
df
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#         released  score    votes             director  \
# ...

# %%
corr_matrix2 = df_numerized.corr(method ="pearson" ) 
sns.heatmap(corr_matrix2,annot=True)
plt.title('correlation matrix for numeric features')
plt.xlabel('movies features')
plt.ylabel('movies features')

plt.show()

# %%
df_numerized.corr().head()
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.029234  0.010996  0.025542  0.025675  0.014450
# rating   -0.029234  1.000000  0.147796  0.019499  0.021996  0.065983
# genre     0.010996  0.147796  1.000000 -0.073167 -0.062167  0.035106
# year      0.025542  0.019499 -0.073167  1.000000  0.987157  0.056386
# released  0.025675  0.021996 -0.062167  0.987157  1.000000  0.063089
#
#              votes  director    writer      star   country    budget  \
# name      0.012615  0.015246  0.012880 -0.006882 -0.025490  0.023392
# rating    0.006031  0.014656 -0.003149  0.009196  0.008230 -0.203946
# genre    -0.135990 -0.008553  0.017578  0.003341 -0.009164 -0.368523
# year      0.206021 -0.038354 -0.025908 -0.032157 -0.066748  0.327722
# released  0.199654 -0.037666 -0.025997 -0.034169 -0.073323  0.314665
#
#              gross   company   runtime  yearcorrect
# name      0.005639  0.021697  0.010850     0.024136
# ...

# %%
corr_matrix3 =df_numerized.corr()
corr_pairs = corr_matrix3.unstack()
corr_pairs.head()
# Out:
# name  name        1.000000
#       rating     -0.029234
#       genre       0.010996
#       year        0.025542
#       released    0.025675
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs.head()
# Out:
# genre   budget   -0.368523
# budget  genre    -0.368523
# genre   gross    -0.244101
# gross   genre    -0.244101
# rating  budget   -0.203946
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs > 0.5) & (sorted_pairs < 1)]
high_corr
# Out:
# gross        votes          0.614751
# votes        gross          0.614751
# budget       gross          0.740247
# gross        budget         0.740247
# released     year           0.987157
# year         released       0.987157
# yearcorrect  year           0.987770
# year         yearcorrect    0.987770
# released     yearcorrect    0.998455
# yearcorrect  released       0.998455
# dtype: float64

# %%
#votes and budgets have the highest correlation to gross earnings
#company has low correlation vs gross earnings
